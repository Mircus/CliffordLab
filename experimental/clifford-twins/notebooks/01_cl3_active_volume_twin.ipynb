# %% [markdown]
# # Cl(3,0) Active-Volume Twin
#
# This notebook is a placeholder. Run the examples first:
#
# ```bash
# python examples/cl3_twin_demo.py
# python examples/folded_triality_demo.py
# ```

# %%
from clifford_twins import *
from clifford_twins.identities import is_associative_on_basis, is_alternative_on_basis
print(is_associative_on_basis(clifford_product))
print(is_associative_on_basis(octonion_twin_product))
print(is_alternative_on_basis(octonion_twin_product))
